# %% [markdown]
# # This code uses a .json file with file names and detected song intervals, then assembles either: 1) recording segments that contain song or 2) entire files that contain song.
#
# ## Both data outputs are saved in the original folder_path.
# - folder_path is a path to a folder that contains all of the .wav file recordings.
# - json_path is a path to a .json file output by a song detector code, which contains each .wav file name from folder_path and, if there was detected song, the time segments with detected song in them.

# %% [markdown]
# ## Option 1: only generate spectrograms of time setgments with detected song.
# ### This code uses the time segments inside of the .json file to combine songs into 1 minute .wav files containing song, then saves those .wav files and generates .pngs of their spectrograms.

# %%
from pathlib import Path
animal_id      = "R10"     # shown in the output filenames
recording_date = "2023-05-23"  # YYYY‑MM‑DD              ↑

# absolute **or** relative path to the folder that holds the .wav files
folder_path = Path(
    "/Volumes/my_own_SSD/UO_stuff/RC12_R10_Comp1/36"
)

# absolute **or** relative path to the JSON file with detected intervals
json_path = Path(
    "/Volumes/my_own_SSD/UO_stuff/RC12_R10_Comp1/36_periodicity_only_detected_song_intervals_combined_segments.json"
)

# %%
#!/usr/bin/env python
# -*- coding: utf‑8 -*-
"""
Slice detected song intervals out of a folder of .wav files, concatenate them,
split into ≤ chunk_duration_sec chunks, and save the chunks with filenames that
embed `animal_id` and `recording_date`, e.g.

    USA5288_2025-04-08_detected_song_segment_3.wav
"""

import json
from pathlib import Path
from typing import Optional, List

import numpy as np
from scipy.io import wavfile

# ────────────────────────────────────────────────────────────────
# USER‑EDITABLE METADATA
# ────────────────────────────────────────────────────────────────
# animal_id      = "USA5207"     # shown in the output filenames
# recording_date = "2025-07-19"  # YYYY‑MM‑DD              ↑

# # absolute **or** relative path to the folder that holds the .wav files
# folder_path = Path(
#     "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33"
# )

# # absolute **or** relative path to the JSON file with detected intervals
# json_path = Path(
#     "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33_periodicity_only_detected_song_intervals_combined_segments.json"
# )
# ────────────────────────────────────────────────────────────────
# RUNTIME SETTINGS
# ────────────────────────────────────────────────────────────────
chunk_duration_sec       = 60      # target length of each output clip
save_partial_final_chunk = True    # keep a trailing < 60‑s chunk?
pad_partial_with_zeros   = False   # …and pad it out to full length?

# ────────────────────────────────────────────────────────────────
# QUICK VALIDATION OF THE TWO CRITICAL PATHS
# ────────────────────────────────────────────────────────────────
if not folder_path.exists():
    raise FileNotFoundError(f"Audio folder not found:\n  {folder_path.resolve()}")

if not json_path.is_file():
    raise FileNotFoundError(f"JSON file not found:\n  {json_path.resolve()}")

# ────────────────────────────────────────────────────────────────
# OUTPUT FOLDER
# ────────────────────────────────────────────────────────────────
output_folder = folder_path / "detected_song_segments"
output_folder.mkdir(parents=True, exist_ok=True)

# ────────────────────────────────────────────────────────────────
# STEP 1 – load JSON with [start, end] pairs (seconds)
# ────────────────────────────────────────────────────────────────
with open(json_path, "r", encoding="utf‑8") as f:
    detected_intervals: dict[str, List[List[float]]] = json.load(f)

# ────────────────────────────────────────────────────────────────
# STEP 2 – extract every detected interval from every file
# ────────────────────────────────────────────────────────────────
detected_segments: List[np.ndarray] = []
sample_rate_reference: Optional[int] = None
missing_files: list[str] = []

for file_name, intervals in detected_intervals.items():
    wav_path = folder_path / file_name
    if not wav_path.exists():
        missing_files.append(file_name)
        continue

    try:
        samplerate, data = wavfile.read(wav_path)

        # use the first file as the reference sample‑rate
        if sample_rate_reference is None:
            sample_rate_reference = samplerate
        elif samplerate != sample_rate_reference:
            raise ValueError(f"Sample‑rate mismatch in {file_name}")

        # stereo → mono
        if data.ndim > 1:
            data = data.mean(axis=1)

        # pull every [start, end] snippet
        for start_time, end_time in intervals:
            start = int(start_time * samplerate)
            end   = int(end_time   * samplerate)
            detected_segments.append(data[start:end])

    except Exception as e:
        print(f"⚠️  Error reading {file_name}: {e}")

# Report any listed but missing files
if missing_files:
    print("\n⚠️  The following files were listed in the JSON but not found in"
          f" {folder_path}:\n  • " + "\n  • ".join(missing_files))

if not detected_segments:
    raise RuntimeError("No detected song segments were found for the paths "
                       "you provided. Double‑check the folder/JSON pairing.")

# ────────────────────────────────────────────────────────────────
# STEP 3 – concatenate & split into ≤ chunk_duration_sec chunks
# ────────────────────────────────────────────────────────────────
concatenated   = np.concatenate(detected_segments)
target_samples = chunk_duration_sec * sample_rate_reference
song_segments  = []

for i in range(0, len(concatenated), target_samples):
    chunk = concatenated[i : i + target_samples]

    if len(chunk) == target_samples:
        # full‑length chunk
        song_segments.append(chunk)

    elif save_partial_final_chunk and len(chunk) > 0:
        # trailing short chunk
        if pad_partial_with_zeros:
            pad_len = target_samples - len(chunk)
            chunk   = np.pad(chunk, (0, pad_len), mode="constant")
        song_segments.append(chunk)

# ────────────────────────────────────────────────────────────────
# STEP 4 – write each chunk to disk with descriptive filename
# ────────────────────────────────────────────────────────────────
for idx, segment in enumerate(song_segments, start=1):
    duration_sec = len(segment) / sample_rate_reference
    suffix       = "_partial" if duration_sec < chunk_duration_sec else ""
    fname = f"{animal_id}_{recording_date}_detected_song_segment_{idx}{suffix}.wav"

    wavfile.write(output_folder / fname,
                  sample_rate_reference,
                  segment.astype(np.int16))

    print(f"✅  Saved {fname}  ({duration_sec:.2f} s)")

print("\nDone!  Segments are in:", output_folder.resolve())
# Out:
# ✅  Saved R10_2023-05-23_detected_song_segment_1.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_2.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_3.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_4.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_5.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_6.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_7.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_8.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_9.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_10.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_11.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_12.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_13.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_14.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_15.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_16.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_17.wav  (60.00 s)
# ✅  Saved R10_2023-05-23_detected_song_segment_18_partial.wav  (45.00 s)
#
# Done!  Segments are in: /Volumes/my_own_SSD/UO_stuff/RC12_R10_Comp1/36/detected_song_segments

# %% [markdown]
# ## Generate the spectrograms:

# %%
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
# """
# Render filtered spectrogram panels for every
# <parent>/detected_song_segments/*.wav **and** draw red dashed lines wherever
# the concatenated audio switches from one original .wav file to the next.

# Required inputs
# ---------------
# parent_folder : Path to the folder that also contains
#                 ├─ detected_song_segments/
#                 └─ <something>.json          (# same JSON you fed the exporter)

# The JSON must have the form::
#     {
#         "original_a.wav": [[s0,e0], [s1,e1], ...],
#         "original_b.wav": [[s2,e2], ...],
#         ...
#     }

# The script re‑creates the exporter’s concatenation logic to know where one
# file stops and the next one starts inside each 60‑s segment.
# """

# from __future__ import annotations

# import re
# from pathlib import Path
# from typing import Dict, List, Tuple

# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.io import wavfile
# from scipy.signal import spectrogram, windows, ellip, filtfilt
# import json
# import tkinter as tk

# # ────────────────────────────────────────────────────────────────
# # USER CONFIG  (edit these three paths / constants)
# # ────────────────────────────────────────────────────────────────
# # parent_folder = Path(
# #     "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33"
# # )
# # json_path = "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33_periodicity_only_detected_song_intervals_combined_segments.json"

# segment_duration    = 10          # seconds per spectrogram panel
# panels_per_fig      = 6           # ⇒ 60 s max per detected segment
# low_cut, high_cut   = 500, 8000   # Hz filter before spectrogram
# cmap_choice         = "binary"

# # ════════════════════════════════════════════════════════════════
# # DERIVED PATHS
# # ════════════════════════════════════════════════════════════════
# segments_folder = folder_path / "detected_song_segments"
# png_folder      = segments_folder / "spectrograms"
# png_folder.mkdir(parents=True, exist_ok=True)

# # ════════════════════════════════════════════════════════════════
# # UTILS
# # ════════════════════════════════════════════════════════════════
# def get_screen_inches() -> Tuple[float, float]:
#     try:
#         root = tk.Tk(); root.withdraw()
#         w, h = root.winfo_screenwidth(), root.winfo_screenheight()
#         root.destroy()
#         return w / 100, h / 100
#     except Exception:
#         return 12, 8

# width_inches, height_inches = get_screen_inches()

# segment_idx_re = re.compile(r"_segment_(\d+)")

# # ════════════════════════════════════════════════════════════════
# # STEP 1 – build boundary map  {segment_number: [times (s), …]}
# #         Each time marks EITHER the start OR the end of a slice
# # ════════════════════════════════════════════════════════════════
# with open(json_path, "r", encoding="utf-8") as f:
#     detected_intervals: Dict[str, List[List[float]]] = json.load(f)

# # grab the sample‑rate once from any segment file
# any_seg = next(segments_folder.glob("*.wav"), None)
# if any_seg is None:
#     raise FileNotFoundError("No *.wav in detected_song_segments/")
# sr, _ = wavfile.read(any_seg)

# SEG_LEN_S   = panels_per_fig * segment_duration          # 60 s
# SEG_LEN_SMP = SEG_LEN_S * sr

# boundary_map: Dict[int, List[float]] = {}
# seg_idx            = 1
# pos_in_seg_samples = 0
# boundaries: List[float] = []

# for src_name, intervals in detected_intervals.items():
#     for start_t, end_t in intervals:
#         slice_len_smp = int(round((end_t - start_t) * sr))
#         remaining = slice_len_smp

#         while remaining > 0:
#             space_left = SEG_LEN_SMP - pos_in_seg_samples
#             take       = min(remaining, space_left)

#             # ─── record start & end of the chunk that will be copied ───
#             slice_start_time = pos_in_seg_samples              / sr
#             slice_end_time   = (pos_in_seg_samples + take)     / sr
#             boundaries.extend([slice_start_time, slice_end_time])

#             # ─── update counters ──────────────────────────────────────
#             pos_in_seg_samples += take
#             remaining          -= take

#             # ─── segment filled? commit & start a fresh one ───────────
#             if pos_in_seg_samples == SEG_LEN_SMP:
#                 # drop potential duplicates & keep ascending order
#                 boundary_map[seg_idx] = sorted(set(boundaries))
#                 seg_idx            += 1
#                 pos_in_seg_samples  = 0
#                 boundaries          = []

# # commit the (possibly shorter) final segment
# if boundaries:
#     boundary_map[seg_idx] = sorted(set(boundaries))


# # ════════════════════════════════════════════════════════════════
# # STEP 2 – process ONE .wav
# # ════════════════════════════════════════════════════════════════
# def process_wav_file(wav_path: Path, boundaries: List[float]):
#     base_name = wav_path.stem
#     sr, data  = wavfile.read(wav_path)
#     if data.ndim > 1:
#         data = data.mean(axis=1)
#     if np.issubdtype(data.dtype, np.integer):
#         data = data.astype(np.float32)

#     nyq = sr / 2
#     b, a = ellip(5, 0.2, 40, [low_cut / nyq, high_cut / nyq], btype="band")
#     data = filtfilt(b, a, data)

#     total_secs   = data.size / sr
#     samples_per_panel = int(segment_duration * sr)
#     n_panels     = min(panels_per_fig, int(np.ceil(total_secs / segment_duration)))

#     fig, axs = plt.subplots(n_panels, 1,
#                             figsize=(width_inches, height_inches),
#                             sharex=True, gridspec_kw={'hspace': 0.0})
#     axs = [axs] if n_panels == 1 else axs

#     for i in range(n_panels):
#         start_samp = i * samples_per_panel
#         seg = data[start_samp : start_samp + samples_per_panel]
#         if seg.size < samples_per_panel:
#             seg = np.pad(seg, (0, samples_per_panel - seg.size))

#         f, t, Sxx = spectrogram(
#             seg, fs=sr,
#             window=windows.gaussian(2048, std=2048/8),
#             nperseg=2048, noverlap=2048 - 119
#         )
#         S_log  = 10 * np.log10(Sxx + np.finfo(float).eps)
#         S_log  = np.clip(S_log, a_min=3, a_max=None)
#         S_norm = (S_log - S_log.min()) / (S_log.ptp() or 1.0)
#         S_norm **= 0.7

#         axs[i].imshow(S_norm, aspect='auto', origin='lower',
#                       extent=[0, segment_duration, f.min(), f.max()],
#                       cmap=cmap_choice)
#         axs[i].set_ylim(0, 11000)
#         axs[i].set_ylabel("Freq [Hz]")

#         # Draw the red dashed boundaries that fall inside this 10‑s panel
#         panel_t0 = i * segment_duration
#         panel_t1 = panel_t0 + segment_duration
#         for b_t in boundaries:
#             if panel_t0 < b_t < panel_t1:
#                 axs[i].axvline(b_t - panel_t0, color='red',
#                                linestyle='--', linewidth=1)

#         if i == n_panels - 1:
#             axs[i].set_xlabel("Time [s]")
#             axs[i].set_xticks(np.linspace(0, segment_duration, 5))

#     fig.suptitle(f"{base_name}  –  Spectrogram ({low_cut}-{high_cut} Hz)",
#                  fontsize=14)
#     fig.tight_layout()

#     out_png = png_folder / f"{base_name}_spectrogram.png"
#     fig.savefig(out_png, dpi=300)
#     plt.close(fig)
#     print("✅", out_png.name)

# # ════════════════════════════════════════════════════════════════
# # STEP 3 – batch over segments
# # ════════════════════════════════════════════════════════════════
# wav_files = sorted(segments_folder.glob("*.wav"))
# if not wav_files:
#     raise FileNotFoundError("No .wav files found in detected_song_segments/")

# print(f"📂 Rendering spectrograms for {len(wav_files)} files …\n")

# for wav_file in wav_files:
#     m = segment_idx_re.search(wav_file.stem)
#     if not m:
#         print("⚠️  Could not parse segment index from", wav_file.name)
#         continue
#     seg_idx = int(m.group(1))
#     boundaries = boundary_map.get(seg_idx, [])
#     process_wav_file(wav_file, boundaries)

# print("\nDone!  PNGs are in:", png_folder.resolve())

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Render filtered spectrogram panels for every
<parent>/detected_song_segments/*.wav and save a PNG for each clip.
(NO red dashed boundaries are drawn.)
"""

from __future__ import annotations

import re
from pathlib import Path
from typing import Dict, List, Tuple

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import spectrogram, windows, ellip, filtfilt
import json
import tkinter as tk

# ────────────────────────────────────────────────────────────────
# USER CONFIG –– EDIT these three items
# ────────────────────────────────────────────────────────────────
# folder_path = Path(
#     "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33"
# )
# json_path = Path(
#     "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/"
#     "33_periodicity_only_detected_song_intervals_combined_segments.json"
# )

segment_duration    = 10          # seconds per spectrogram panel
panels_per_fig      = 6           # ⇒ 60 s max per detected segment
low_cut, high_cut   = 500, 8000   # Hz filter before spectrogram
cmap_choice         = "binary"

# ════════════════════════════════════════════════════════════════
# DERIVED PATHS
# ════════════════════════════════════════════════════════════════
segments_folder = folder_path / "detected_song_segments"
png_folder      = segments_folder / "spectrograms"
png_folder.mkdir(parents=True, exist_ok=True)

# ════════════════════════════════════════════════════════════════
# UTILS
# ════════════════════════════════════════════════════════════════
def get_screen_inches() -> Tuple[float, float]:
    try:
        root = tk.Tk(); root.withdraw()
        w, h = root.winfo_screenwidth(), root.winfo_screenheight()
        root.destroy()
        return w / 100, h / 100
    except Exception:
        return 12, 8

width_inches, height_inches = get_screen_inches()
segment_idx_re = re.compile(r"_segment_(\d+)")

# ════════════════════════════════════════════════════════════════
# BUILD boundary map  {segment_number: [times (s), …]}
#   (We still compute it for completeness, but boundaries are no
#   longer drawn.)
# ════════════════════════════════════════════════════════════════
with open(json_path, "r", encoding="utf-8") as f:
    detected_intervals: Dict[str, List[List[float]]] = json.load(f)

any_seg = next(segments_folder.glob("*.wav"), None)
if any_seg is None:
    raise FileNotFoundError("No *.wav in detected_song_segments/")
sr, _ = wavfile.read(any_seg)

SEG_LEN_S   = panels_per_fig * segment_duration          # 60 s
SEG_LEN_SMP = SEG_LEN_S * sr

boundary_map: Dict[int, List[float]] = {}
seg_idx            = 1
pos_in_seg_samples = 0
boundaries: List[float] = []

for src_name, intervals in detected_intervals.items():
    for start_t, end_t in intervals:
        slice_len_smp = int(round((end_t - start_t) * sr))
        remaining = slice_len_smp

        while remaining > 0:
            space_left = SEG_LEN_SMP - pos_in_seg_samples
            take       = min(remaining, space_left)

            # record start & end of the chunk that will be copied
            slice_start_time = pos_in_seg_samples              / sr
            slice_end_time   = (pos_in_seg_samples + take)     / sr
            boundaries.extend([slice_start_time, slice_end_time])

            pos_in_seg_samples += take
            remaining          -= take

            if pos_in_seg_samples == SEG_LEN_SMP:
                boundary_map[seg_idx] = sorted(set(boundaries))
                seg_idx            += 1
                pos_in_seg_samples  = 0
                boundaries          = []

if boundaries:
    boundary_map[seg_idx] = sorted(set(boundaries))

# ════════════════════════════════════════════════════════════════
# PROCESS ONE .wav  (no red dashed lines drawn)
# ════════════════════════════════════════════════════════════════
def process_wav_file(wav_path: Path):
    base_name = wav_path.stem
    sr, data  = wavfile.read(wav_path)
    if data.ndim > 1:
        data = data.mean(axis=1)
    if np.issubdtype(data.dtype, np.integer):
        data = data.astype(np.float32)

    nyq = sr / 2
    b, a = ellip(5, 0.2, 40, [low_cut / nyq, high_cut / nyq], btype="band")
    data = filtfilt(b, a, data)

    total_secs        = data.size / sr
    samples_per_panel = int(segment_duration * sr)
    n_panels          = min(panels_per_fig, int(np.ceil(total_secs / segment_duration)))

    fig, axs = plt.subplots(
        n_panels, 1, figsize=(width_inches, height_inches),
        sharex=True, gridspec_kw={'hspace': 0.0}
    )
    axs = [axs] if n_panels == 1 else axs

    for i in range(n_panels):
        start_samp = i * samples_per_panel
        seg = data[start_samp : start_samp + samples_per_panel]
        if seg.size < samples_per_panel:
            seg = np.pad(seg, (0, samples_per_panel - seg.size))

        f, t, Sxx = spectrogram(
            seg, fs=sr,
            window=windows.gaussian(2048, std=2048/8),
            nperseg=2048, noverlap=2048 - 119
        )
        S_log  = 10 * np.log10(Sxx + np.finfo(float).eps)
        S_log  = np.clip(S_log, a_min=3, a_max=None)
        S_norm = (S_log - S_log.min()) / (S_log.ptp() or 1.0)
        S_norm **= 0.7

        axs[i].imshow(
            S_norm, aspect='auto', origin='lower',
            extent=[0, segment_duration, f.min(), f.max()],
            cmap=cmap_choice
        )
        axs[i].set_ylim(0, 11000)
        axs[i].set_ylabel("Freq [Hz]")

        if i == n_panels - 1:
            axs[i].set_xlabel("Time [s]")
            axs[i].set_xticks(np.linspace(0, segment_duration, 5))

    fig.suptitle(f"{base_name}  –  Spectrogram ({low_cut}-{high_cut} Hz)", fontsize=14)
    fig.tight_layout()

    out_png = png_folder / f"{base_name}_spectrogram.png"
    fig.savefig(out_png, dpi=300)
    plt.close(fig)
    print("✅", out_png.name)

# ════════════════════════════════════════════════════════════════
# BATCH over segments
# ════════════════════════════════════════════════════════════════
wav_files = sorted(segments_folder.glob("*.wav"))
if not wav_files:
    raise FileNotFoundError("No .wav files found in detected_song_segments/")

print(f"📂 Rendering spectrograms for {len(wav_files)} files …\n")

for wav_file in wav_files:
    process_wav_file(wav_file)

print("\nDone!  PNGs are in:", png_folder.resolve())
# Out:
# 📂 Rendering spectrograms for 18 files …
#
# ✅ R10_2023-05-23_detected_song_segment_1_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_10_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_11_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_12_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_13_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_14_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_15_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_16_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_17_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_18_partial_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_2_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_3_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_4_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_5_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_6_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_7_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_8_spectrogram.png
# ✅ R10_2023-05-23_detected_song_segment_9_spectrogram.png
#
# Done!  PNGs are in: /Volumes/my_own_SSD/UO_stuff/RC12_R10_Comp1/36/detected_song_segments/spectrograms

# %% [markdown]
# # Option 2: This portion combines all .wav files containing songs into 1-minute recordings, then  generates spectrograms of them.

# %%
# import os, json
# import numpy as np
# from scipy.io import wavfile
# from pathlib import Path   # (unused but often handy)

# # ╔══════════════════════════════════════════════════════════════════════╗
# # CONFIG ── update these two paths only
# # ╚══════════════════════════════════════════════════════════════════════╝
# # folder_path = '/your/recordings/folder'
# # json_path   = '/your/detector_output.json'

# # ── derived paths ──────────────────────────────────────────────────────
# output_folder       = os.path.join(folder_path, 'detected_song_files_full_recordings')
# os.makedirs(output_folder, exist_ok=True)
# metadata_output_path = os.path.join(output_folder, 'segment_metadata.json')

# # ╔══════════════════════════════════════════════════════════════════════╗
# # LOAD detector JSON  →  {wav_file : [[start,end], …]}
# # ╚══════════════════════════════════════════════════════════════════════╝
# with open(json_path) as f:
#     detected_intervals = json.load(f)

# # process files in deterministic order
# file_names = sorted(detected_intervals.keys())

# # ╔══════════════════════════════════════════════════════════════════════╗
# # READ all wavs into memory (could be streamed if very large files)
# # ╚══════════════════════════════════════════════════════════════════════╝
# audio_queue            = []            # [(file_name, data)]
# sample_rate_reference  = None

# for fn in file_names:
#     wav_path = os.path.join(folder_path, fn)
#     if not os.path.exists(wav_path):
#         print(f"⚠️  Missing file: {fn}")
#         continue
#     try:
#         sr, data = wavfile.read(wav_path)
#         if sample_rate_reference is None:
#             sample_rate_reference = sr
#         elif sr != sample_rate_reference:
#             raise ValueError(f"Sample‑rate mismatch in {fn} ({sr} vs {sample_rate_reference})")
#         if data.ndim > 1:                       # stereo → mono
#             data = data.mean(axis=1)
#         audio_queue.append((fn, data.astype(np.float32)))
#     except Exception as e:
#         print(f"⚠️  Error reading {fn}: {e}")

# if not audio_queue:
#     raise RuntimeError("No audio files were loaded successfully.")

# # ╔══════════════════════════════════════════════════════════════════════╗
# # CHUNKING variables & helpers
# # ╚══════════════════════════════════════════════════════════════════════╝
# minute_samples      = 60 * sample_rate_reference
# leftover            = np.array([], dtype=np.float32)
# leftover_provenance = []      # list of dicts: {"source_file", "range_start", "range_end"}
# segment_metadata    = {}
# chunk_count         = 0

# def get_song_segments_within_range(source_file, range_start, range_end):
#     """Return detector intervals (sec) that overlap [range_start, range_end) in sample coords,
#        expressed relative to the *start of that range*."""
#     out = []
#     for t_start, t_end in detected_intervals.get(source_file, []):
#         s_start = int(t_start * sample_rate_reference)
#         s_end   = int(t_end   * sample_rate_reference)
#         ov_start = max(s_start, range_start)
#         ov_end   = min(s_end,   range_end)
#         if ov_start < ov_end:
#             out.append([
#                 round((ov_start - range_start) / sample_rate_reference, 3),
#                 round((ov_end   - range_start) / sample_rate_reference, 3)
#             ])
#     return out

# def finalize_chunk(chunk_data, provenance, song_segments, idx):
#     fname = f'detected_song_minute_{idx+1}.wav'
#     fpath = os.path.join(output_folder, fname)
#     wavfile.write(fpath, sample_rate_reference, chunk_data.astype(np.int16))
#     segment_metadata[fname] = {
#         "source_files": provenance,
#         "song_segments_in_chunk": song_segments
#     }
#     print(f"✅  Saved {fname}")

# # ╔══════════════════════════════════════════════════════════════════════╗
# # MAIN loop – stitch files, slice 60‑s chunks, preserve provenance
# # ╚══════════════════════════════════════════════════════════════════════╝
# for file_name, data in audio_queue:

#     # 1) build new "combined" buffer = leftover + current file
#     combined         = np.concatenate([leftover, data])
#     combined_ranges  = []          # [{"source_file", "range_start", "range_end"}]
#     offset           = 0

#     # carry forward *all* leftover provenance
#     for prov in leftover_provenance:
#         dur = prov["range_end"] - prov["range_start"]
#         combined_ranges.append({
#             "source_file": prov["source_file"],
#             "range_start": offset,
#             "range_end":   offset + dur
#         })
#         offset += dur

#     # append current file’s span
#     combined_ranges.append({
#         "source_file": file_name,
#         "range_start": offset,
#         "range_end":   offset + len(data)
#     })

#     # 2) slice full‑minute chunks
#     cursor = 0
#     while cursor + minute_samples <= len(combined):
#         chunk               = combined[cursor:cursor + minute_samples]
#         chunk_provenance    = []
#         chunk_song_segments = []

#         chunk_start = cursor
#         chunk_end   = cursor + minute_samples

#         for rng in combined_ranges:
#             src_start, src_end = rng["range_start"], rng["range_end"]
#             ov_start = max(chunk_start, src_start)
#             ov_end   = min(chunk_end,   src_end)
#             if ov_start < ov_end:   # overlap exists
#                 # provenance entry
#                 rel_start_sec = (ov_start - chunk_start) / sample_rate_reference
#                 rel_end_sec   = (ov_end   - chunk_start) / sample_rate_reference
#                 chunk_provenance.append({
#                     "source_file": rng["source_file"],
#                     "time_range_in_chunk_seconds": [round(rel_start_sec,3),
#                                                    round(rel_end_sec,3)]
#                 })
#                 # song segments from this slice
#                 slice_rel_start = ov_start - src_start
#                 slice_rel_end   = ov_end   - src_start
#                 for seg in get_song_segments_within_range(
#                         rng["source_file"], slice_rel_start, slice_rel_end):
#                     chunk_song_segments.append([
#                         round(seg[0] + rel_start_sec, 3),
#                         round(seg[1] + rel_start_sec, 3)
#                     ])

#         finalize_chunk(chunk, chunk_provenance, chunk_song_segments, chunk_count)
#         chunk_count += 1
#         cursor      += minute_samples

#     # 3) whatever is left < 60 s → carry to next iteration
#     leftover = combined[cursor:]
#     leftover_provenance = []
#     if len(leftover) > 0:
#         for rng in combined_ranges:
#             if rng["range_end"] > cursor:                      # part survives
#                 leftover_provenance.append({
#                     "source_file": rng["source_file"],
#                     "range_start": max(0,   rng["range_start"] - cursor),
#                     "range_end":   rng["range_end"] - cursor
#                 })

# # ╔══════════════════════════════════════════════════════════════════════╗
# # FINAL (possibly padded) chunk made from leftover audio
# # ╚══════════════════════════════════════════════════════════════════════╝
# if len(leftover) > 0:
#     padded = np.pad(leftover, (0, minute_samples - len(leftover)), mode="constant")
#     final_prov  = []
#     final_segs  = []
#     for rng in leftover_provenance:
#         p_start_sec = rng["range_start"] / sample_rate_reference
#         p_end_sec   = rng["range_end"]   / sample_rate_reference
#         final_prov.append({
#             "source_file": rng["source_file"],
#             "time_range_in_chunk_seconds": [round(p_start_sec,3), round(p_end_sec,3)]
#         })
#         for seg in get_song_segments_within_range(
#                 rng["source_file"], 0, rng["range_end"] - rng["range_start"]):
#             final_segs.append([
#                 round(seg[0] + p_start_sec, 3),
#                 round(seg[1] + p_start_sec, 3)
#             ])
#     finalize_chunk(padded, final_prov, final_segs, chunk_count)

# # ╔══════════════════════════════════════════════════════════════════════╗
# # WRITE master metadata file
# # ╚══════════════════════════════════════════════════════════════════════╝
# with open(metadata_output_path, "w") as f:
#     json.dump(segment_metadata, f, indent=2)

# print(f"📄  Metadata saved to: {metadata_output_path}")

# %%
#!/usr/bin/env python
# -*- coding: utf‑8 -*-

"""
Split one or more long .wav recordings into consecutive 60‑second clips
and keep track of (1) which original file(s) contributed to each clip and
(2) where song was detected inside each clip.

The output clips are named:
    <animal_id>_<recording_date>_detected_song_segment_<N>.wav
and a JSON file `segment_metadata.json` is written alongside them.
"""

import os, json
import numpy as np
from scipy.io import wavfile
from pathlib import Path   # (unused here, but handy for future tweaks)

# ╔══════════════════════════════════════════════════════════════════════╗
# CONFIG –– update the four values below
# ╚══════════════════════════════════════════════════════════════════════╝
# folder_path   = "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33"        # directory with raw .wav files
# json_path     = "/Volumes/my_own_SSD/UO_stuff/nerve_transections/USA5207/33_periodicity_only_detected_song_intervals_combined_segments.json"      # detector output (song intervals)
# animal_id     = 'USA5207'                          # e.g. 'USA5207'
# recording_date = '2025-07-19'                      # e.g. 'YYYY‑MM‑DD'

# ── derived paths ──────────────────────────────────────────────────────
output_folder        = os.path.join(folder_path, 'detected_song_files_full_recordings')
os.makedirs(output_folder, exist_ok=True)
metadata_output_path = os.path.join(output_folder, 'segment_metadata.json')

# ╔══════════════════════════════════════════════════════════════════════╗
# LOAD detector JSON  →  {wav_file : [[start,end], …]}
# ╚══════════════════════════════════════════════════════════════════════╝
with open(json_path, 'r') as f:
    detected_intervals = json.load(f)

# deterministic processing order
file_names = sorted(detected_intervals.keys())

# ╔══════════════════════════════════════════════════════════════════════╗
# READ all wavs into memory (could be streamed if very large files)
# ╚══════════════════════════════════════════════════════════════════════╝
audio_queue           = []      # list of tuples (file_name, mono_float32_data)
sample_rate_reference = None

for fn in file_names:
    wav_path = os.path.join(folder_path, fn)
    if not os.path.exists(wav_path):
        print(f"⚠️  Missing file: {fn}")
        continue
    try:
        sr, data = wavfile.read(wav_path)
        if sample_rate_reference is None:
            sample_rate_reference = sr
        elif sr != sample_rate_reference:
            raise ValueError(f"Sample‑rate mismatch in {fn} ({sr} vs {sample_rate_reference})")

        # stereo → mono
        if data.ndim > 1:
            data = data.mean(axis=1)

        audio_queue.append((fn, data.astype(np.float32)))
    except Exception as e:
        print(f"⚠️  Error reading {fn}: {e}")

if not audio_queue:
    raise RuntimeError("No audio files were loaded successfully.")

# ╔══════════════════════════════════════════════════════════════════════╗
# CHUNKING variables & helpers
# ╚══════════════════════════════════════════════════════════════════════╝
minute_samples      = 60 * sample_rate_reference
leftover            = np.array([], dtype=np.float32)
leftover_provenance = []      # list of dicts: {"source_file", "range_start", "range_end"}
segment_metadata    = {}
chunk_count         = 0

def get_song_segments_within_range(source_file, range_start, range_end):
    """Return detector intervals (sec) that overlap [range_start, range_end) in sample
    coordinates, expressed relative to the *start* of that range."""
    out = []
    for t_start, t_end in detected_intervals.get(source_file, []):
        s_start = int(t_start * sample_rate_reference)
        s_end   = int(t_end   * sample_rate_reference)
        ov_start = max(s_start, range_start)
        ov_end   = min(s_end,   range_end)
        if ov_start < ov_end:
            out.append([
                round((ov_start - range_start) / sample_rate_reference, 3),
                round((ov_end   - range_start) / sample_rate_reference, 3)
            ])
    return out

def finalize_chunk(chunk_data, provenance, song_segments, idx,
                   animal_id, recording_date):
    """Write one 60‑s clip to disk and log its metadata."""
    fname = (
        f"{animal_id}_{recording_date}_detected_song_segment_{idx+1}.wav"
    )
    fpath = os.path.join(output_folder, fname)

    # ensure int16 range
    chunk_int16 = np.clip(chunk_data, -32768, 32767).astype(np.int16)
    wavfile.write(fpath, sample_rate_reference, chunk_int16)

    segment_metadata[fname] = {
        "source_files": provenance,
        "song_segments_in_chunk": song_segments
    }
    print(f"✅  Saved {fname}")

# ╔══════════════════════════════════════════════════════════════════════╗
# MAIN loop –– stitch files, slice 60‑s chunks, preserve provenance
# ╚══════════════════════════════════════════════════════════════════════╝
for file_name, data in audio_queue:

    # 1) build new "combined" buffer = leftover + current file
    combined        = np.concatenate([leftover, data])
    combined_ranges = []          # [{"source_file", "range_start", "range_end"}]
    offset          = 0

    # carry forward *all* leftover provenance
    for prov in leftover_provenance:
        dur = prov["range_end"] - prov["range_start"]
        combined_ranges.append({
            "source_file": prov["source_file"],
            "range_start": offset,
            "range_end":   offset + dur
        })
        offset += dur

    # append current file’s span
    combined_ranges.append({
        "source_file": file_name,
        "range_start": offset,
        "range_end":   offset + len(data)
    })

    # 2) slice full‑minute chunks
    cursor = 0
    while cursor + minute_samples <= len(combined):
        chunk               = combined[cursor:cursor + minute_samples]
        chunk_provenance    = []
        chunk_song_segments = []

        chunk_start = cursor
        chunk_end   = cursor + minute_samples

        for rng in combined_ranges:
            src_start, src_end = rng["range_start"], rng["range_end"]
            ov_start = max(chunk_start, src_start)
            ov_end   = min(chunk_end,   src_end)
            if ov_start < ov_end:   # overlap exists
                # provenance entry
                rel_start_sec = (ov_start - chunk_start) / sample_rate_reference
                rel_end_sec   = (ov_end   - chunk_start) / sample_rate_reference
                chunk_provenance.append({
                    "source_file": rng["source_file"],
                    "time_range_in_chunk_seconds": [
                        round(rel_start_sec, 3),
                        round(rel_end_sec,   3)
                    ]
                })

                # song segments within this overlap
                slice_rel_start = ov_start - src_start
                slice_rel_end   = ov_end   - src_start
                for seg in get_song_segments_within_range(
                        rng["source_file"], slice_rel_start, slice_rel_end):
                    chunk_song_segments.append([
                        round(seg[0] + rel_start_sec, 3),
                        round(seg[1] + rel_start_sec, 3)
                    ])

        finalize_chunk(chunk, chunk_provenance, chunk_song_segments,
                       chunk_count, animal_id, recording_date)
        chunk_count += 1
        cursor      += minute_samples

    # 3) whatever is left (< 60 s) → carry to next iteration
    leftover = combined[cursor:]
    leftover_provenance = []
    if len(leftover) > 0:
        for rng in combined_ranges:
            if rng["range_end"] > cursor:      # part survives
                leftover_provenance.append({
                    "source_file": rng["source_file"],
                    "range_start": max(0, rng["range_start"] - cursor),
                    "range_end":   rng["range_end"] - cursor
                })

# ╔══════════════════════════════════════════════════════════════════════╗
# FINAL (possibly padded) chunk made from leftover audio
# ╚══════════════════════════════════════════════════════════════════════╝
if len(leftover) > 0:
    padded = np.pad(
        leftover, (0, minute_samples - len(leftover)),
        mode="constant"
    )

    final_prov, final_segs = [], []
    for rng in leftover_provenance:
        p_start_sec = rng["range_start"] / sample_rate_reference
        p_end_sec   = rng["range_end"]   / sample_rate_reference
        final_prov.append({
            "source_file": rng["source_file"],
            "time_range_in_chunk_seconds": [
                round(p_start_sec, 3),
                round(p_end_sec,   3)
            ]
        })
        for seg in get_song_segments_within_range(
                rng["source_file"], 0, rng["range_end"] - rng["range_start"]):
            final_segs.append([
                round(seg[0] + p_start_sec, 3),
                round(seg[1] + p_start_sec, 3)
            ])

    finalize_chunk(padded, final_prov, final_segs,
                   chunk_count, animal_id, recording_date)

# ╔══════════════════════════════════════════════════════════════════════╗
# WRITE master metadata file
# ╚══════════════════════════════════════════════════════════════════════╝
with open(metadata_output_path, 'w') as f:
    json.dump(segment_metadata, f, indent=2)

print(f"📄  Metadata saved to: {metadata_output_path}")
# Out:
# ✅  Saved R10_2023-05-23_detected_song_segment_1.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_2.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_3.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_4.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_5.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_6.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_7.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_8.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_9.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_10.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_11.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_12.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_13.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_14.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_15.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_16.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_17.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_18.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_19.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_20.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_21.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_22.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_23.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_24.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_25.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_26.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_27.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_28.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_29.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_30.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_31.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_32.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_33.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_34.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_35.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_36.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_37.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_38.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_39.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_40.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_41.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_42.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_43.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_44.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_45.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_46.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_47.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_48.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_49.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_50.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_51.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_52.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_53.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_54.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_55.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_56.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_57.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_58.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_59.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_60.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_61.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_62.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_63.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_64.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_65.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_66.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_67.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_68.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_69.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_70.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_71.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_72.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_73.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_74.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_75.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_76.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_77.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_78.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_79.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_80.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_81.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_82.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_83.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_84.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_85.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_86.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_87.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_88.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_89.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_90.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_91.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_92.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_93.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_94.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_95.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_96.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_97.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_98.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_99.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_100.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_101.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_102.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_103.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_104.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_105.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_106.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_107.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_108.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_109.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_110.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_111.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_112.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_113.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_114.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_115.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_116.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_117.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_118.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_119.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_120.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_121.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_122.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_123.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_124.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_125.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_126.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_127.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_128.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_129.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_130.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_131.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_132.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_133.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_134.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_135.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_136.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_137.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_138.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_139.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_140.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_141.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_142.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_143.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_144.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_145.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_146.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_147.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_148.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_149.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_150.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_151.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_152.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_153.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_154.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_155.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_156.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_157.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_158.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_159.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_160.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_161.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_162.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_163.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_164.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_165.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_166.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_167.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_168.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_169.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_170.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_171.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_172.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_173.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_174.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_175.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_176.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_177.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_178.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_179.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_180.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_181.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_182.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_183.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_184.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_185.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_186.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_187.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_188.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_189.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_190.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_191.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_192.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_193.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_194.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_195.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_196.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_197.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_198.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_199.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_200.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_201.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_202.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_203.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_204.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_205.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_206.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_207.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_208.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_209.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_210.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_211.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_212.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_213.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_214.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_215.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_216.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_217.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_218.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_219.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_220.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_221.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_222.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_223.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_224.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_225.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_226.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_227.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_228.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_229.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_230.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_231.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_232.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_233.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_234.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_235.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_236.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_237.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_238.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_239.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_240.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_241.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_242.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_243.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_244.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_245.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_246.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_247.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_248.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_249.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_250.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_251.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_252.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_253.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_254.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_255.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_256.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_257.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_258.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_259.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_260.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_261.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_262.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_263.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_264.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_265.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_266.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_267.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_268.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_269.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_270.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_271.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_272.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_273.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_274.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_275.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_276.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_277.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_278.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_279.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_280.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_281.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_282.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_283.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_284.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_285.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_286.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_287.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_288.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_289.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_290.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_291.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_292.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_293.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_294.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_295.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_296.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_297.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_298.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_299.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_300.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_301.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_302.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_303.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_304.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_305.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_306.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_307.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_308.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_309.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_310.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_311.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_312.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_313.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_314.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_315.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_316.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_317.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_318.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_319.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_320.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_321.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_322.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_323.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_324.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_325.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_326.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_327.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_328.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_329.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_330.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_331.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_332.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_333.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_334.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_335.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_336.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_337.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_338.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_339.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_340.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_341.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_342.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_343.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_344.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_345.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_346.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_347.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_348.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_349.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_350.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_351.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_352.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_353.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_354.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_355.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_356.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_357.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_358.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_359.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_360.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_361.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_362.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_363.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_364.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_365.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_366.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_367.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_368.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_369.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_370.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_371.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_372.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_373.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_374.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_375.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_376.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_377.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_378.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_379.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_380.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_381.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_382.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_383.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_384.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_385.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_386.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_387.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_388.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_389.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_390.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_391.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_392.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_393.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_394.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_395.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_396.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_397.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_398.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_399.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_400.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_401.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_402.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_403.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_404.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_405.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_406.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_407.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_408.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_409.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_410.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_411.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_412.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_413.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_414.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_415.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_416.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_417.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_418.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_419.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_420.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_421.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_422.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_423.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_424.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_425.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_426.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_427.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_428.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_429.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_430.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_431.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_432.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_433.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_434.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_435.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_436.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_437.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_438.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_439.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_440.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_441.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_442.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_443.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_444.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_445.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_446.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_447.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_448.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_449.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_450.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_451.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_452.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_453.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_454.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_455.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_456.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_457.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_458.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_459.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_460.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_461.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_462.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_463.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_464.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_465.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_466.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_467.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_468.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_469.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_470.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_471.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_472.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_473.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_474.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_475.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_476.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_477.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_478.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_479.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_480.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_481.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_482.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_483.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_484.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_485.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_486.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_487.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_488.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_489.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_490.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_491.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_492.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_493.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_494.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_495.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_496.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_497.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_498.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_499.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_500.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_501.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_502.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_503.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_504.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_505.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_506.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_507.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_508.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_509.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_510.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_511.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_512.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_513.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_514.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_515.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_516.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_517.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_518.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_519.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_520.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_521.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_522.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_523.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_524.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_525.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_526.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_527.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_528.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_529.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_530.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_531.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_532.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_533.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_534.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_535.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_536.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_537.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_538.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_539.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_540.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_541.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_542.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_543.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_544.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_545.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_546.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_547.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_548.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_549.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_550.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_551.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_552.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_553.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_554.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_555.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_556.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_557.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_558.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_559.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_560.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_561.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_562.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_563.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_564.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_565.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_566.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_567.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_568.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_569.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_570.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_571.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_572.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_573.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_574.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_575.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_576.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_577.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_578.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_579.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_580.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_581.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_582.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_583.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_584.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_585.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_586.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_587.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_588.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_589.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_590.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_591.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_592.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_593.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_594.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_595.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_596.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_597.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_598.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_599.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_600.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_601.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_602.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_603.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_604.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_605.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_606.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_607.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_608.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_609.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_610.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_611.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_612.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_613.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_614.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_615.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_616.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_617.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_618.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_619.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_620.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_621.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_622.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_623.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_624.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_625.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_626.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_627.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_628.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_629.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_630.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_631.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_632.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_633.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_634.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_635.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_636.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_637.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_638.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_639.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_640.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_641.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_642.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_643.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_644.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_645.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_646.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_647.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_648.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_649.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_650.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_651.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_652.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_653.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_654.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_655.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_656.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_657.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_658.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_659.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_660.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_661.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_662.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_663.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_664.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_665.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_666.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_667.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_668.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_669.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_670.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_671.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_672.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_673.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_674.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_675.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_676.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_677.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_678.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_679.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_680.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_681.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_682.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_683.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_684.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_685.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_686.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_687.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_688.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_689.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_690.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_691.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_692.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_693.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_694.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_695.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_696.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_697.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_698.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_699.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_700.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_701.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_702.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_703.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_704.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_705.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_706.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_707.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_708.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_709.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_710.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_711.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_712.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_713.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_714.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_715.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_716.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_717.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_718.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_719.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_720.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_721.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_722.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_723.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_724.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_725.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_726.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_727.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_728.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_729.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_730.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_731.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_732.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_733.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_734.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_735.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_736.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_737.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_738.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_739.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_740.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_741.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_742.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_743.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_744.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_745.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_746.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_747.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_748.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_749.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_750.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_751.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_752.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_753.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_754.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_755.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_756.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_757.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_758.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_759.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_760.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_761.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_762.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_763.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_764.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_765.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_766.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_767.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_768.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_769.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_770.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_771.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_772.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_773.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_774.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_775.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_776.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_777.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_778.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_779.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_780.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_781.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_782.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_783.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_784.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_785.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_786.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_787.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_788.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_789.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_790.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_791.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_792.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_793.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_794.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_795.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_796.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_797.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_798.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_799.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_800.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_801.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_802.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_803.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_804.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_805.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_806.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_807.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_808.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_809.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_810.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_811.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_812.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_813.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_814.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_815.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_816.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_817.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_818.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_819.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_820.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_821.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_822.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_823.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_824.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_825.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_826.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_827.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_828.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_829.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_830.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_831.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_832.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_833.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_834.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_835.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_836.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_837.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_838.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_839.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_840.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_841.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_842.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_843.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_844.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_845.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_846.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_847.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_848.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_849.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_850.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_851.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_852.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_853.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_854.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_855.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_856.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_857.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_858.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_859.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_860.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_861.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_862.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_863.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_864.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_865.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_866.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_867.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_868.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_869.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_870.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_871.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_872.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_873.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_874.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_875.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_876.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_877.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_878.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_879.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_880.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_881.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_882.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_883.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_884.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_885.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_886.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_887.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_888.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_889.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_890.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_891.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_892.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_893.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_894.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_895.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_896.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_897.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_898.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_899.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_900.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_901.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_902.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_903.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_904.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_905.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_906.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_907.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_908.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_909.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_910.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_911.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_912.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_913.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_914.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_915.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_916.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_917.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_918.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_919.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_920.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_921.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_922.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_923.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_924.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_925.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_926.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_927.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_928.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_929.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_930.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_931.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_932.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_933.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_934.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_935.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_936.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_937.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_938.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_939.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_940.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_941.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_942.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_943.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_944.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_945.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_946.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_947.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_948.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_949.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_950.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_951.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_952.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_953.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_954.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_955.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_956.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_957.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_958.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_959.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_960.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_961.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_962.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_963.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_964.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_965.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_966.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_967.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_968.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_969.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_970.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_971.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_972.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_973.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_974.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_975.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_976.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_977.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_978.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_979.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_980.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_981.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_982.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_983.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_984.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_985.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_986.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_987.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_988.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_989.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_990.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_991.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_992.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_993.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_994.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_995.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_996.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_997.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_998.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_999.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1000.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1001.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1002.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1003.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1004.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1005.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1006.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1007.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1008.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1009.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1010.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1011.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1012.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1013.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1014.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1015.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1016.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1017.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1018.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1019.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1020.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1021.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1022.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1023.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1024.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1025.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1026.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1027.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1028.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1029.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1030.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1031.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1032.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1033.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1034.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1035.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1036.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1037.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1038.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1039.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1040.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1041.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1042.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1043.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1044.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1045.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1046.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1047.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1048.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1049.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1050.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1051.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1052.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1053.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1054.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1055.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1056.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1057.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1058.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1059.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1060.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1061.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1062.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1063.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1064.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1065.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1066.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1067.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1068.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1069.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1070.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1071.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1072.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1073.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1074.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1075.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1076.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1077.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1078.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1079.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1080.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1081.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1082.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1083.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1084.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1085.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1086.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1087.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1088.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1089.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1090.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1091.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1092.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1093.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1094.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1095.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1096.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1097.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1098.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1099.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1100.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1101.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1102.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1103.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1104.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1105.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1106.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1107.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1108.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1109.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1110.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1111.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1112.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1113.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1114.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1115.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1116.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1117.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1118.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1119.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1120.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1121.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1122.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1123.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1124.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1125.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1126.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1127.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1128.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1129.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1130.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1131.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1132.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1133.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1134.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1135.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1136.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1137.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1138.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1139.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1140.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1141.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1142.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1143.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1144.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1145.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1146.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1147.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1148.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1149.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1150.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1151.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1152.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1153.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1154.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1155.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1156.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1157.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1158.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1159.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1160.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1161.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1162.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1163.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1164.wav
# ✅  Saved R10_2023-05-23_detected_song_segment_1165.wav
# 📄  Metadata saved to: /Volumes/my_own_SSD/UO_stuff/RC12_R10_Comp1/36/detected_song_files_full_recordings/segment_metadata.json
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Generate the spectrogram

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
Batch‑render spectrograms for detected‑song minute clips and (re)name the
clips themselves with a clearer convention:

    <animal_id>_<recording_date>_detected_song_file_minute_<n>.wav
"""

import os, json
from pathlib import Path
from typing import List, Tuple

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import spectrogram, windows, ellip, filtfilt
import tkinter as tk

# ────────────────────────────────────────────────────────────────
# variables `animal_id`, `recording_date`, `folder_path`, `json_path`
# were defined in a previous notebook cell
# ────────────────────────────────────────────────────────────────

# ────────────────────────────────────────────────────────────────
# PATHS  –– join with `/` instead of `+`
# ────────────────────────────────────────────────────────────────
base_folder    = folder_path / "detected_song_files_full_recordings"   # ← FIXED
spectrogram_out = base_folder / "spectrograms"
spectrogram_out.mkdir(exist_ok=True)

# Optional metadata JSON
metadata_json = base_folder / "segment_metadata.json"
if metadata_json.is_file():
    with metadata_json.open("r", encoding="utf-8") as f:
        segment_metadata = json.load(f)
else:
    segment_metadata = {}

# ────────────────────────────────────────────────────────────────
# Figure‑size helper
# ────────────────────────────────────────────────────────────────
def get_screen_inches() -> Tuple[float, float]:
    try:
        root = tk.Tk(); root.withdraw()
        w, h = root.winfo_screenwidth(), root.winfo_screenheight()
        root.destroy()
        return w / 100, h / 100
    except Exception:
        return 12, 8

width_inches, height_inches = get_screen_inches()

# ────────────────────────────────────────────────────────────────
# Spectrogram rendering for one clip
# ────────────────────────────────────────────────────────────────
def render_clip(
    wav_path: Path,
    segment_duration: int = 10,
    panels_per_fig: int = 6,
    low_cut: int = 500,
    high_cut: int = 8000,
) -> None:

    base_name = wav_path.stem
    sr, data  = wavfile.read(wav_path)
    if data.ndim > 1:
        data = data.mean(axis=1)
    if np.issubdtype(data.dtype, np.integer):
        data = data.astype(np.float32)

    # band‑pass
    nyq = sr / 2
    b, a = ellip(5, 0.2, 40, [low_cut / nyq, high_cut / nyq], btype="band")
    data = filtfilt(b, a, data)

    total_secs        = data.size / sr
    samples_per_panel = int(segment_duration * sr)
    n_panels          = min(panels_per_fig, int(np.ceil(total_secs / segment_duration)))

    # annotations
    meta_key       = wav_path.name
    song_intervals = segment_metadata.get(meta_key, {}).get("song_segments_in_chunk", [])
    boundary_lines = [
        src["time_range_in_chunk_seconds"][1]
        for src in segment_metadata.get(meta_key, {}).get("source_files", [])
        if "time_range_in_chunk_seconds" in src
    ]

    fig, axs = plt.subplots(
        n_panels, 1, figsize=(width_inches, height_inches),
        sharex=True, gridspec_kw={"hspace": 0.0}
    )
    axs = [axs] if n_panels == 1 else axs

    for idx in range(n_panels):
        start_sample = idx * samples_per_panel
        panel = data[start_sample : start_sample + samples_per_panel]
        if panel.size < samples_per_panel:                 # zero‑pad last panel
            panel = np.pad(panel, (0, samples_per_panel - panel.size))

        f, t, Sxx = spectrogram(
            panel, fs=sr,
            window=windows.gaussian(2048, std=2048 / 8),
            nperseg=2048, noverlap=2048 - 119,
        )
        S_log  = 10 * np.log10(Sxx + np.finfo(float).eps)
        S_log  = np.clip(S_log, a_min=3, a_max=None)
        S_norm = (S_log - S_log.min()) / (S_log.ptp() or 1)
        S_norm **= 0.7

        axs[idx].imshow(
            S_norm, aspect="auto", origin="lower",
            extent=[0, segment_duration, f.min(), f.max()],
            cmap="binary",
        )
        axs[idx].set_ylim(0, 11_000)
        axs[idx].set_ylabel("Freq [Hz]")

        # yellow song spans
        p0, p1 = idx * segment_duration, (idx + 1) * segment_duration
        for s0, s1 in song_intervals:
            if s0 < p1 and s1 > p0:
                x0, x1 = max(0, s0 - p0), min(segment_duration, s1 - p0)
                axs[idx].axvspan(x0, x1, color="yellow", alpha=0.1)

        # (If you removed red boundaries earlier, delete this block.)
        for b in boundary_lines:
            if p0 < b < p1:
                axs[idx].axvline(b - p0, color="red", linestyle="--", linewidth=1.2)

        if idx == n_panels - 1:
            axs[idx].set_xlabel("Time [s]")
            axs[idx].set_xticks(np.linspace(0, segment_duration, 5))

    fig.suptitle(f"{base_name} – Spectrogram ({low_cut}-{high_cut} Hz)", fontsize=14)
    fig.tight_layout()

    out_png = spectrogram_out / f"{base_name}_spectrogram.png"
    fig.savefig(out_png, dpi=300)
    plt.close(fig)
    print(f"✅ spectrogram → {out_png.name}")

# ────────────────────────────────────────────────────────────────
# Batch rename clips, update metadata map, and render
# ────────────────────────────────────────────────────────────────
wav_files: List[Path] = sorted(base_folder.glob("*.wav"))
if not wav_files:
    raise FileNotFoundError(f"No .wav clips found in {base_folder}")

print(f"\n📂 Found {len(wav_files)} clips – renaming & rendering …\n")

for idx, old_path in enumerate(wav_files, start=1):
    new_name = f"{animal_id}_{recording_date}_detected_song_file_minute_{idx}.wav"
    new_path = old_path.with_name(new_name)

    if old_path.name != new_name:           # rename on disk
        old_path.rename(new_path)

    # keep metadata mapping in sync
    if old_path.name in segment_metadata and new_name not in segment_metadata:
        segment_metadata[new_name] = segment_metadata[old_path.name]

    render_clip(new_path)

print("\nDone!  Spectrograms in:", spectrogram_out.resolve())
# Out:
# 📂 Found 1165 clips – renaming & rendering …
#
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_1_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_2_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_3_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_4_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_5_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_6_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_7_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_8_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_9_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_10_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_11_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_12_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_13_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_14_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_15_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_16_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_17_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_18_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_19_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_20_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_21_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_22_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_23_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_24_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_25_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_26_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_27_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_28_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_29_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_30_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_31_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_32_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_33_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_34_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_35_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_36_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_37_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_38_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_39_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_40_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_41_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_42_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_43_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_44_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_45_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_46_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_47_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_48_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_49_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_50_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_51_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_52_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_53_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_54_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_55_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_56_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_57_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_58_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_59_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_60_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_61_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_62_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_63_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_64_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_65_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_66_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_67_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_68_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_69_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_70_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_71_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_72_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_73_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_74_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_75_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_76_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_77_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_78_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_79_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_80_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_81_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_82_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_83_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_84_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_85_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_86_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_87_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_88_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_89_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_90_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_91_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_92_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_93_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_94_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_95_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_96_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_97_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_98_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_99_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_100_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_101_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_102_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_103_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_104_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_105_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_106_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_107_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_108_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_109_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_110_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_111_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_112_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_113_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_114_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_115_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_116_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_117_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_118_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_119_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_120_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_121_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_122_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_123_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_124_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_125_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_126_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_127_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_128_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_129_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_130_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_131_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_132_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_133_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_134_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_135_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_136_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_137_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_138_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_139_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_140_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_141_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_142_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_143_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_144_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_145_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_146_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_147_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_148_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_149_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_150_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_151_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_152_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_153_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_154_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_155_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_156_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_157_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_158_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_159_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_160_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_161_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_162_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_163_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_164_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_165_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_166_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_167_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_168_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_169_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_170_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_171_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_172_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_173_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_174_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_175_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_176_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_177_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_178_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_179_spectrogram.png
# ✅ spectrogram → R10_2023-05-23_detected_song_file_minute_180_spectrogram.png

# %% [markdown]
# ### Trying out different color scales for better song visibility:

# %%
# import numpy as np
# import os
# from pathlib import Path
# from scipy.io import wavfile
# from scipy.signal import spectrogram, windows, ellip, filtfilt
# import matplotlib.pyplot as plt
# import tkinter as tk
# import json

# # ── Utility: approximate screen size in inches (assumes 100 dpi) ─────────────
# def get_screen_resolution():
#     root = tk.Tk(); root.withdraw()
#     w_px, h_px = root.winfo_screenwidth(), root.winfo_screenheight()
#     root.destroy()
#     return w_px / 100, h_px / 100

# width_inches, height_inches = get_screen_resolution()

# # ── Load your segment metadata (if you have one) ─────────────────────────────
# # For example:
# # with open("path/to/segment_metadata.json") as f:
# #     segment_metadata = json.load(f)
# segment_metadata = {}  # replace with your actual metadata dict

# def process_wav_file(file_path, spectrogram_folder,
#                      segment_duration=10,
#                      low_cut=500, high_cut=8000):
#     try:
#         base_name = Path(file_path).stem
#         sr, data = wavfile.read(file_path)
#         if data.ndim > 1:
#             data = data.mean(axis=1)

#         # === Band‑pass filter ===
#         nyq = sr / 2
#         b, a = ellip(5, 0.2, 40,
#                      [low_cut/nyq, high_cut/nyq],
#                      btype='band')
#         data = filtfilt(b, a, data)

#         # === Setup segments ===
#         total_secs = data.size / sr
#         seg_samps = int(segment_duration * sr)
#         nseg = min(6, int(np.ceil(total_secs / segment_duration)))
#         out_path = Path(spectrogram_folder) / f"{base_name}_spectrogram.png"

#         fig, axs = plt.subplots(nseg, 1,
#                                 figsize=(width_inches, height_inches),
#                                 sharex=True,
#                                 gridspec_kw={'hspace': 0})
#         if nseg == 1:
#             axs = [axs]

#         # retrieve any song intervals / boundaries
#         key = f"{base_name}.wav"
#         song_intervals = segment_metadata.get(key, {}).get("song_segments_in_chunk", [])
#         boundaries = [src["time_range_in_chunk_seconds"][1]
#                       for src in segment_metadata.get(key, {}).get("source_files", [])
#                       if "time_range_in_chunk_seconds" in src]

#         for i in range(nseg):
#             start = i * seg_samps
#             end = start + seg_samps
#             chunk = np.zeros(seg_samps, dtype=data.dtype)
#             if start < data.size:
#                 chunk[:max(0, min(seg_samps, data.size - start))] = data[start:end]

#             # ── compute spectrogram ──────────────────────────────────────────
#             f, t, Sxx = spectrogram(
#                 chunk,
#                 fs=sr,
#                 window=windows.gaussian(2048, std=2048/8),
#                 nperseg=2048,
#                 noverlap=2048 - 119
#             )

#             # ── convert to dB and clamp dynamic range ────────────────────────
#             Sxx_dB = 10 * np.log10(Sxx + np.finfo(float).eps)
#             vmax = Sxx_dB.max()
#             vmin = vmax - 60   # adjust dynamic range (e.g. top 60 dB)
#             axs[i].imshow(
#                 Sxx_dB,
#                 aspect='auto',
#                 origin='lower',
#                 extent=[0, segment_duration, f.min(), f.max()],
#                 cmap='gray_r',
#                 vmin=vmin,
#                 vmax=vmax
#             )
#             axs[i].set_ylim(0, 11000)

#             # ── yellow highlights ───────────────────────────────────────────
#             panel_off = i * segment_duration
#             for s0, s1 in song_intervals:
#                 if s0 < panel_off + segment_duration and s1 > panel_off:
#                     x0 = max(0, s0 - panel_off)
#                     x1 = min(segment_duration, s1 - panel_off)
#                     axs[i].axvspan(x0, x1, color='yellow', alpha=0.1)

#             # ── red boundaries ───────────────────────────────────────────────
#             for btime in boundaries:
#                 if panel_off < btime < panel_off + segment_duration:
#                     axs[i].axvline(btime - panel_off,
#                                    color='red',
#                                    linestyle='--',
#                                    linewidth=1.2)

#             axs[i].set_ylabel('Freq [Hz]')
#             if i == nseg - 1:
#                 axs[i].set_xlabel('Time [sec]')
#                 axs[i].set_xticks(np.linspace(0, segment_duration, 5))

#         fig.suptitle(f'{base_name} – Spectrogram (Filtered {low_cut}-{high_cut} Hz)', fontsize=14)
#         fig.tight_layout()
#         fig.savefig(out_path, dpi=300)
#         plt.close(fig)
#         print(f"✅ Saved: {out_path}")

#     except Exception as e:
#         print(f"❌ Error processing {file_path} – {e}")

# def batch_process_folder(folder_path, segment_duration=10):
#     spectrogram_folder = Path(folder_path) / "spectrograms"
#     spectrogram_folder.mkdir(parents=True, exist_ok=True)

#     wavs = list(Path(folder_path).glob("*.wav"))
#     if not wavs:
#         print("No .wav files found.")
#         return

#     print(f"\n📂 Processing {len(wavs)} files in {folder_path}\n")
#     for wf in wavs:
#         process_wav_file(str(wf), str(spectrogram_folder),
#                          segment_duration=segment_duration)

# # === USER CONFIGURE & RUN ===
# if __name__ == "__main__":
#     # point this to your folder of .wav files
#     #folder = "/path/to/your/wav_folder"
#     batch_process_folder(spectrogram_output_folder, segment_duration=10)
